# %% [markdown]
# <a href="https://colab.research.google.com/github/yudits10/BerTopic2023/blob/main/BerTopic2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bertopic
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.4/143.4 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 88.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.8/90.8 kB 9.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 9.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached Cython-0.29.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 101.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 82.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 36.3 MB/s eta 0:00:00
# ...

# %%
# !pip install bertopic[visualization]
# Out:
# ...
# WARNING: bertopic 0.15.0 does not provide the extra 'visualization'
# ...

# %%
#import packages

import pandas as pd
import numpy as np
from bertopic import BERTopic
import string

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('./drive/MyDrive/20-Oktober-2023/Reviews_Filter.csv')
# Out:
# Mounted at /content/drive

# %%
df.head(10)
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# 5   6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
# 6   7  B006K2ZZ7K  A1SP2KVKFXXRU1                David C. Sullivan
# 7   8  B006K2ZZ7K  A3JRGQVEQN31IQ               Pamela G. Williams
# 8   9  B000E7L2R4  A1MZYO9TZK0BBI                         R. James
# 9  10  B00171APVA  A21BT40VZCCYT4                    Carol A. Reed
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# ...

# %%
def clean_text(text):
  delete_dict ={sp_character: '' for sp_character in string.punctuation}
  delete_dict[' '] = ' '
  table = str.maketrans(delete_dict)
  text1 = text.translate(table)
  textArr = text1.split()
  text2 = ' '.join([w for w in textArr if (not w.isdigit() and (not w.isdigit() and len(w)>3))])

  return text2.lower()

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
df.dropna(axis = 0, how = 'any', inplace=True)

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
df['Text'] = df['Text'].apply(clean_text)

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# %%
def remove_stopwords(text):
  textArr = text.split(' ')
  rem_text = " ".join([i for i in textArr if i not in stop_words])
  return rem_text

df['Text'] = df['Text'].apply(remove_stopwords)

# %%
df['Text'].head()
# Out:
# 0    bought several vitality canned food products f...
# 1    product arrived labeled jumbo salted peanutsth...
# 2    confection around centuries light pillowy citr...
# 3    looking secret ingredient robitussin believe f...
# 4    great taffy great price wide assortment yummy ...
# Name: Text, dtype: object

# %%
model = BERTopic(verbose=True)

docs = df.Text.to_list()
topics, probabilities = model.fit_transform(docs)
# Out:
# ...
# Batches:   0%|          | 0/469 [00:00<?, ?it/s]
# 2023-10-24 08:54:44,950 - BERTopic - Transformed documents to Embeddings
# 2023-10-24 08:55:31,435 - BERTopic - Reduced dimensionality
# 2023-10-24 08:55:32,077 - BERTopic - Clustered reduced embeddings

# %%
model.get_topic_freq().head(11)
# Out:
#      Topic  Count
# 0       -1   5693
# 88       0    416
# 32       1    359
# 81       2    275
# 5        3    270
# 11       4    256
# 51       5    253
# 45       6    234
# 120      7    155
# 6        8    153
# 12       9    145

# %%
model.get_topic(0)
# Out:
# [('cocoa', 0.061716022344023215),
#  ('chocolate', 0.04685904203469987),
#  ('dark', 0.016089639322951394),
#  ('grove', 0.015977179825274777),
#  ('stephens', 0.014257754510219394),
#  ('square', 0.014090447615037657),
#  ('keurig', 0.014066327567812618),
#  ('milk', 0.013735276973478625),
#  ('chocolates', 0.012750111200112508),
#  ('kcup', 0.01041859507899403)]

# %%
model.get_topic(1)
# Out:
# [('orange', 0.04208837624721558),
#  ('juice', 0.03797313181872558),
#  ('soda', 0.03672464408753664),
#  ('tangerine', 0.030262362447893446),
#  ('switch', 0.029252779782476448),
#  ('carbonated', 0.026797218343391407),
#  ('drink', 0.023866782801690103),
#  ('carbonation', 0.017839539792713518),
#  ('fruit', 0.015611387152033215),
#  ('sugar', 0.014272394418143)]

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model = BERTopic(nr_topics=20)

# %%
topics, probabilities = model.fit_transform(docs)
# Out:
# 2023-10-24 09:08:30,072 - BERTopic - Transformed documents to Embeddings
# 2023-10-24 09:08:48,058 - BERTopic - Reduced dimensionality
# 2023-10-24 09:08:48,702 - BERTopic - Clustered reduced embeddings
# 2023-10-24 09:08:51,686 - BERTopic - Reduced number of topics from 171 to 20

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
